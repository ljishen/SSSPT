# %% [markdown]
# # Throughput Test Report

# %% [markdown]
# ## Experiment Environment

# %% [markdown]
# ### Part 1: Server-based Experiment
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Platform</b></th>
#   </tr>
#   <tr>
#     <td><b>Ref Test Platform</b></td>
#     <td>HP ProLiant DL360p Gen8 655651-B21</td>
#   </tr>
#   <tr>
#     <td><b>CPU</b></td>
#     <td>2x "IvyBridge" Intel® Xeon® E5-2630 v2 @ 2.6GHz</td>
#   </tr>
#   <tr>
#     <td><b>Memory</b></td>
#     <td>64GB DDR3</td>
#   </tr>
#   <tr>
#     <td><b>Operating System</b></td>
#     <td>Ubuntu 16.04.5</td>
#   </tr>
#   <tr>
#     <td><b>Kernel Release</b></td>
#     <td>4.4.132-0404132-generic</td>
#   </tr>
#   <tr>
#     <td><b>Test SW</b></td>
#     <td>fio-3.8</td>
#   </tr>
#   <tr>
#     <td><b>HBA</b></td>
#     <td>StarTech USB 3.0 Card PEXUSB3S24<br>Ugreen 20231 USB 3.0 to SATA 3.0 Converter Adapter</td>
#   </tr>
#   <tr>
#     <td><b>PCIe</b></td>
#     <td>Gen 3.0</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Device Under Test</b></th>
#   </tr>
#   <tr>
#     <td><b>Mfgr</b></td>
#     <td>Toshiba HG6</td>
#   </tr>
#   <tr>
#     <td><b>Model No.</b></td>
#     <td>THNSNJ256G8NU</td>
#   </tr>
#   <tr>
#     <td><b>S/N</b></td>
#     <td>15NS100WT9JW</td>
#   </tr>
#   <tr>
#     <td><b>Firmware Ver.</b></td>
#     <td>JUGB0101</td>
#   </tr>
#   <tr>
#     <td><b>Capacity</b></td>
#     <td>256 GB</td>
#   </tr>
#   <tr>
#     <td><b>Interface</b></td>
#     <td>SATA Rev 3.0<br></td>
#   </tr>
#   <tr>
#     <td><b>NAND Type</b></td>
#     <td>MLC</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <th colspan="2"><b>Set Up Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%<br></td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 1</b></td>
#     <td>SEQ 128KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32</td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 2</b></td>
#     <td>SEQ 1024KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32<br></td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%</td>
#   </tr>
#   <tr>
#     <td><b>Test Stimulus 1</b></td>
#     <td>SEQ</td>
#   </tr>
#   <tr>
#     <td>    Block Size (Outer Loop)</td>
#     <td>128KB, 1024KB</td>
#   </tr>
#   <tr>
#     <td>    R/W Mix (Inner Loop)</td>
#     <td>100:0, 0:100</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32</td>
#   </tr>
#   <tr>
#     <td>    Steady State</td>
#     <td>1 - 5</td>
#   </tr>
# </table>
#
# <p align="center">
#     <a href="https://docs.google.com/drawings/d/1dmuNkRi_mTinLUXaOD2Nk66fgFZ73rfmXhRimUxwXj8/edit?usp=sharing"><img src="images/expr_setup_hp.png" alt="Baseline Expr Setup (HP ProLiant)"></a>
# </p>

# %%
# %run 'common/plot_throughput.py'

profiles_dirname = 'hp/throughput/2'

plot_ss_convergence(profiles_dirname)
plot_ss_measurement_window(profiles_dirname)
plot_tp_measurement(profiles_dirname)
# Out:
# ---
#             <table>
#               <caption><b>Block Size: 4KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>160.820 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>176.902 MB/s (Max) / 144.738 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>162.536 MB/s (Max) / 159.073 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>1.180% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.9486 x + 158</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 8KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>241.617 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>265.779 MB/s (Max) / 217.456 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>245.235 MB/s (Max) / 240.146 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.363% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.4381 x + 240.3</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 16KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>319.442 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>351.386 MB/s (Max) / 287.498 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>320.572 MB/s (Max) / 317.829 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.301% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.4803 x + 318</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 32KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>350.862 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>385.948 MB/s (Max) / 315.776 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>356.479 MB/s (Max) / 348.311 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.673% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -1.18 x + 354.4</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 128KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>365.896 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>402.485 MB/s (Max) / 329.306 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>366.791 MB/s (Max) / 364.675 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.007% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.0123 x + 365.9</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 1024KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>372.881 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>410.169 MB/s (Max) / 335.593 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>373.639 MB/s (Max) / 371.868 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.046% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.08525 x + 372.6</td>
#               </tr>
#             </table><br/>
# ---
#             <table>
#               <caption><b>Block Size: 4KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>153.913 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>169.304 MB/s (Max) / 138.522 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>156.411 MB/s (Max) / 153.152 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.753% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.5798 x + 155.7</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 8KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>217.047 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>238.752 MB/s (Max) / 195.343 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>218.613 MB/s (Max) / 213.241 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.986% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 1.07 x + 213.8</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 16KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>254.734 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>280.207 MB/s (Max) / 229.260 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>255.059 MB/s (Max) / 254.538 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.055% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.07051 x + 254.9</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 32KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>268.808 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>295.689 MB/s (Max) / 241.928 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>270.842 MB/s (Max) / 262.344 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.042% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.05664 x + 269</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 128KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>269.901 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>296.891 MB/s (Max) / 242.911 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>273.068 MB/s (Max) / 262.692 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>1.779% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 2.4 x + 262.7</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 1024KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>275.571 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>303.129 MB/s (Max) / 248.014 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>276.312 MB/s (Max) / 275.083 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.032% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.04385 x + 275.7</td>
#               </tr>
#             </table><br/>
# ---

# %% [markdown]
# ## Notes
#
# ### Definition of ***Steady State***
#
# ```
# A device is said to be in Steady State when, for the dependent variable (y)
# being tracked:
#     a) Range(y) is less than 10% of Ave(y): Max(y)-Min(y) within the
#        Measurement Window is no more than 10% of the Ave(y) within the
#        Measurement Window; and
#     b) Slope(y) is less than 10%: Max(y)-Min(y), where Max(y) and Min(y) are
#        the maximum and minimum values on the best linear curve fit of the
#        y-values within the Measurement Window, is within 10% of Ave(y) value
#        within the Measurement Window.
# ```

# %% [markdown]
# ## References
#
# - [Solid State Storage (SSS) Performance Test Specification (PTS) v2.0.1](https://www.snia.org/sites/default/files/technical_work/PTS/SSS_PTS_2.0.1.pdf)
