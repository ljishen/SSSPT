# %% [markdown]
# # IOPS Test Report

# %% [markdown]
# ## Experiment Environment

# %% [markdown]
# <table>
#   <tr>
#     <th colspan="2"><b>Set Up Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%<br></td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 1</b></td>
#     <td>SEQ 128KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 2 / QD 16</td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%</td>
#   </tr>
#   <tr>
#     <td><b>Test Stimulus 1</b></td>
#     <td>RND</td>
#   </tr>
#   <tr>
#     <td>    Block Size (Outer Loop)</td>
#     <td>1024KB, 128KB, 64KB, 32KB, 16KB, 8KB, 4KB, 512B</td>
#   </tr>
#   <tr>
#     <td>    R/W Mix (Inner Loop)</td>
#     <td>100/0, 95/5, 65/35, 50/50, 35/65, 5/95, 0/100</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 2 / QD 16</td>
#   </tr>
# </table>

# %%
# %run 'common/plot_iops.py'

profiles_dirname = 'rockpro64/iops/5'

plot_ss_convergence(profiles_dirname)
plot_ss_measurement_window(profiles_dirname)
plot_measurement_window_tabular(profiles_dirname)
plot_measurement_window_2d(profiles_dirname)
plot_measurement_window_3d(profiles_dirname)
# Out:
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
#         <table>
#           <caption><b>Block Size = 4KB, R/W Mix % = 0:100</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>1 - 5</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>23925.451</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>26317.996 (Max) / 21532.906 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>25012.416 (Max) / 23204.960 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>1.373% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# 164.2 x + 2.343e+04</td>
#           </tr>
#         </table><br/>
# ---
#         <table>
#           <caption><b>Block Size = 64KB, R/W Mix % = 65:35</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>2 - 6</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>4029.430</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>4432.373 (Max) / 3626.487 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>4139.929 (Max) / 3817.278 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>3.236% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# 65.2 x + 3769</td>
#           </tr>
#         </table><br/>
# ---
#         <table>
#           <caption><b>Block Size = 1024KB, R/W Mix % = 100:0</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>1 - 5</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>416.509</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>458.160 (Max) / 374.858 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>416.571 (Max) / 416.441 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>0.012% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# -0.02539 x + 416.6</td>
#           </tr>
#         </table><br/>
# ---
#     <table>
#       <caption><b>IOPS - ALL RW Mix & BS - Tabular Data</b></caption>
#       <tr>
#         <td rowspan="2"><b>Block Size</b></td>
#         <td colspan="7"><b>Read / Write Mix %</b></td>
#       </tr>
#       <tr>
#         <td><b>100/0</b></td><td><b>95/5</b></td><td><b>65/35</b></td><td><b>50/50</b></td><td><b>35/65</b></td><td><b>5/95</b></td><td><b>0/100</b></td>
#       </tr>
#       <tr><td><b>1024KB</b></td><td>416.509</td><td>395.553</td><td>339.837</td><td>316.935</td><td>302.774</td><td>270.790</td><td>273.768</td></tr><tr><td><b>128KB</b></td><td>3194.702</td><td>2927.160</td><td>2237.525</td><td>2079.057</td><td>1940.251</td><td>1837.803</td><td>1882.098</td></tr><tr><td><b>64KB</b></td><td>6088.308</td><td>5527.092</td><td>4029.430</td><td>3733.273</td><td>3460.815</td><td>3508.514</td><td>3564.947</td></tr><tr><td><b>32KB</b></td><td>11562.864</td><td>10488.566</td><td>7529.897</td><td>6827.494</td><td>6518.670</td><td>6505.786</td><td>6804.695</td></tr><tr><td><b>16KB</b></td><td>21449.240</td><td>19118.535</td><td>14055.298</td><td>13610.408</td><td>13485.483</td><td>12468.076</td><td>12592.038</td></tr><tr><td><b>8KB</b></td><td>26286.228</td><td>25416.350</td><td>21601.341</td><td>21112.141</td><td>21871.151</td><td>17846.325</td><td>17209.436</td></tr><tr><td><b>4KB</b></td><td>28410.622</td><td>27769.363</td><td>26458.418</td><td>26873.614</td><td>27388.088</td><td>24720.724</td><td>23925.451</td></tr><tr><td><b>512B</b></td><td>29949.987</td><td>29472.150</td><td>27261.708</td><td>27519.078</td><td>28412.753</td><td>24359.850</td><td>23403.407</td></tr>
#     </table>
# ---
# ---

# %% [markdown]
# ## Notes
#
# ### Definition of ***Steady State***
#
# ```
# A device is said to be in Steady State when, for the dependent variable (y)
# being tracked:
#     a) Range(y) is less than 10% of Ave(y): Max(y)-Min(y) within the
#        Measurement Window is no more than 10% of the Ave(y) within the
#        Measurement Window; and
#     b) Slope(y) is less than 10%: Max(y)-Min(y), where Max(y) and Min(y) are
#        the maximum and minimum values on the best linear curve fit of the
#        y-values within the Measurement Window, is within 10% of Ave(y) value
#        within the Measurement Window.
# ```

# %% [markdown]
# ## References
#
# - [Solid State Storage (SSS) Performance Test Specification (PTS) v2.0.1](https://www.snia.org/sites/default/files/technical_work/PTS/SSS_PTS_2.0.1.pdf)
