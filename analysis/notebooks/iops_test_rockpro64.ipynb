# %% [markdown]
# # IOPS Test Report

# %% [markdown]
# ## Experiment Environment

# %% [markdown]
# <table>
#   <tr>
#     <th colspan="2"><b>Set Up Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%<br></td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 1</b></td>
#     <td>SEQ 128KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 2 / QD 16</td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%</td>
#   </tr>
#   <tr>
#     <td><b>Test Stimulus 1</b></td>
#     <td>SEQ</td>
#   </tr>
#   <tr>
#     <td>    Block Size (Outer Loop)</td>
#     <td>1024KB, 128KB, 64KB, 32KB, 16KB, 8KB, 4KB, 512B</td>
#   </tr>
#   <tr>
#     <td>    R/W Mix (Inner Loop)</td>
#     <td>100/0, 95/5, 65/35, 50/50, 35/65, 5/95, 0/100</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 2 / QD 16</td>
#   </tr>
# </table>

# %%
# %run 'common/plot_iops.py'

profiles_dirname = 'rockpro64/iops/1'

plot_ss_convergence(profiles_dirname)
plot_ss_measurement_window(profiles_dirname)
plot_measurement_window_tabular(profiles_dirname)
plot_measurement_window_2d(profiles_dirname)
plot_measurement_window_3d(profiles_dirname)
# Out:
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
#         <table>
#           <caption><b>Block Size = 4KB, R/W Mix % = 0:100</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>1 - 5</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>22943.772</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>25238.149 (Max) / 20649.394 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>23526.975 (Max) / 22222.230 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>0.647% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# 74.18 x + 2.272e+04</td>
#           </tr>
#         </table><br/>
# ---
#         <table>
#           <caption><b>Block Size = 64KB, R/W Mix % = 65:35</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>5 - 9</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>4095.001</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>4504.501 (Max) / 3685.501 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>4147.314 (Max) / 4024.081 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>0.914% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# 18.72 x + 3964</td>
#           </tr>
#         </table><br/>
# ---
#         <table>
#           <caption><b>Block Size = 1024KB, R/W Mix % = 100:0</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>1 - 5</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>416.528</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>458.181 (Max) / 374.875 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>416.549 (Max) / 416.511 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>0.004% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# -0.008039 x + 416.6</td>
#           </tr>
#         </table><br/>
# ---
#     <table>
#       <caption><b>IOPS - ALL RW Mix & BS - Tabular Data</b></caption>
#       <tr>
#         <td rowspan="2"><b>Block Size</b></td>
#         <td colspan="7"><b>Read / Write Mix %</b></td>
#       </tr>
#       <tr>
#         <td><b>100/0</b></td><td><b>95/5</b></td><td><b>65/35</b></td><td><b>50/50</b></td><td><b>35/65</b></td><td><b>5/95</b></td><td><b>0/100</b></td>
#       </tr>
#       <tr><td><b>1024KB</b></td><td>416.528</td><td>398.548</td><td>342.006</td><td>304.021</td><td>297.243</td><td>267.614</td><td>250.024</td></tr><tr><td><b>128KB</b></td><td>3196.473</td><td>2862.447</td><td>2130.785</td><td>2014.434</td><td>1719.772</td><td>1764.254</td><td>1836.254</td></tr><tr><td><b>64KB</b></td><td>6088.581</td><td>5470.268</td><td>4095.001</td><td>3541.800</td><td>3371.922</td><td>3255.151</td><td>3476.361</td></tr><tr><td><b>32KB</b></td><td>11382.654</td><td>10461.815</td><td>7322.303</td><td>6704.193</td><td>6348.344</td><td>6391.315</td><td>6366.895</td></tr><tr><td><b>16KB</b></td><td>21442.139</td><td>18881.145</td><td>13896.970</td><td>13314.227</td><td>12580.427</td><td>11888.225</td><td>11321.571</td></tr><tr><td><b>8KB</b></td><td>26398.046</td><td>24808.268</td><td>21101.386</td><td>20650.699</td><td>20182.282</td><td>16042.947</td><td>13764.079</td></tr><tr><td><b>4KB</b></td><td>28563.625</td><td>27235.128</td><td>25609.772</td><td>26145.443</td><td>26109.211</td><td>22901.081</td><td>22943.772</td></tr><tr><td><b>512B</b></td><td>30158.053</td><td>28753.449</td><td>26545.708</td><td>27554.633</td><td>26978.619</td><td>22262.764</td><td>19994.738</td></tr>
#     </table>
# ---
# ---

# %% [markdown]
# ## Notes
#
# ### Definition of ***Steady State***
#
# ```
# A device is said to be in Steady State when, for the dependent variable (y)
# being tracked:
#     a) Range(y) is less than 10% of Ave(y): Max(y)-Min(y) within the
#        Measurement Window is no more than 10% of the Ave(y) within the
#        Measurement Window; and
#     b) Slope(y) is less than 10%: Max(y)-Min(y), where Max(y) and Min(y) are
#        the maximum and minimum values on the best linear curve fit of the
#        y-values within the Measurement Window, is within 10% of Ave(y) value
#        within the Measurement Window.
# ```

# %% [markdown]
# ## References
#
# - [Solid State Storage (SSS) Performance Test Specification (PTS) v2.0.1](https://www.snia.org/sites/default/files/technical_work/PTS/SSS_PTS_2.0.1.pdf)
