# %% [markdown]
# # IOPS Test Report

# %% [markdown]
# ## Experiment Environment

# %% [markdown]
# ### Part 1: Server-based Experiment
#
# <table>
#   <tr>
#     <th colspan="2"><b>Set Up Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%<br></td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 1</b></td>
#     <td>SEQ 128KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 2 / QD 16</td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%</td>
#   </tr>
#   <tr>
#     <td><b>Test Stimulus 1</b></td>
#     <td>RND</td>
#   </tr>
#   <tr>
#     <td>    Block Size (Outer Loop)</td>
#     <td>1024KB, 128KB, 64KB, 32KB, 16KB, 8KB, 4KB, 512B</td>
#   </tr>
#   <tr>
#     <td>    R/W Mix (Inner Loop)</td>
#     <td>100/0, 95/5, 65/35, 50/50, 35/65, 5/95, 0/100</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 2 / QD 16</td>
#   </tr>
# </table>

# %%
# %run 'common/plot_iops.py'

profiles_dirname = 'hp/iops/3'

plot_ss_convergence(profiles_dirname)
plot_ss_measurement_window(profiles_dirname)
plot_measurement_window_tabular(profiles_dirname)
plot_measurement_window_2d(profiles_dirname)
plot_measurement_window_3d(profiles_dirname)
# Out:
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
#         <table>
#           <caption><b>Block Size = 4KB, R/W Mix % = 0:100</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>1 - 5</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>27559.521</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>30315.473 (Max) / 24803.569 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>27888.502 (Max) / 26594.890 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>0.468% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# 64.52 x + 2.737e+04</td>
#           </tr>
#         </table><br/>
# ---
#         <table>
#           <caption><b>Block Size = 64KB, R/W Mix % = 65:35</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>2 - 6</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>4039.379</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>4443.317 (Max) / 3635.441 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>4137.770 (Max) / 3855.957 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>2.547% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# 51.45 x + 3834</td>
#           </tr>
#         </table><br/>
# ---
#         <table>
#           <caption><b>Block Size = 1024KB, R/W Mix % = 100:0</b></caption>
#           <tr>
#             <td><b>Measurement Window</b></td>
#             <td>1 - 5</td>
#           </tr>
#           <tr>
#             <td><b>Ave. value in Measurement Window</b></td>
#             <td>372.194</td>
#           </tr>
#           <tr>
#             <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#             <td>409.413 (Max) / 334.974 (Min)</td>
#           </tr>
#           <tr>
#             <td><b>Measured range in Measurement Window</b></td>
#             <td>373.223 (Max) / 371.836 (Min)  (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#             <td>0.115% (<b>pass</b>)</td>
#           </tr>
#           <tr>
#             <td><b>Least Squares Linear Fit Formula</b></td>
#             <td>
# -0.2134 x + 372.8</td>
#           </tr>
#         </table><br/>
# ---
#     <table>
#       <caption><b>IOPS - ALL RW Mix & BS - Tabular Data</b></caption>
#       <tr>
#         <td rowspan="2"><b>Block Size</b></td>
#         <td colspan="7"><b>Read / Write Mix %</b></td>
#       </tr>
#       <tr>
#         <td><b>100/0</b></td><td><b>95/5</b></td><td><b>65/35</b></td><td><b>50/50</b></td><td><b>35/65</b></td><td><b>5/95</b></td><td><b>0/100</b></td>
#       </tr>
#       <tr><td><b>1024KB</b></td><td>372.194</td><td>355.812</td><td>301.122</td><td>285.186</td><td>277.241</td><td>255.558</td><td>258.544</td></tr><tr><td><b>128KB</b></td><td>2937.995</td><td>2726.297</td><td>2153.915</td><td>1958.607</td><td>1854.972</td><td>1728.073</td><td>1749.538</td></tr><tr><td><b>64KB</b></td><td>5769.470</td><td>5295.644</td><td>4039.379</td><td>3651.959</td><td>3448.524</td><td>3342.567</td><td>3362.258</td></tr><tr><td><b>32KB</b></td><td>11206.055</td><td>10278.686</td><td>7570.996</td><td>6978.322</td><td>6634.531</td><td>6493.170</td><td>6573.717</td></tr><tr><td><b>16KB</b></td><td>20475.047</td><td>19202.717</td><td>14199.098</td><td>13355.261</td><td>13170.741</td><td>11942.712</td><td>11994.755</td></tr><tr><td><b>8KB</b></td><td>31986.087</td><td>30386.538</td><td>25867.187</td><td>24578.507</td><td>23506.142</td><td>19835.705</td><td>19633.170</td></tr><tr><td><b>4KB</b></td><td>35739.838</td><td>34933.911</td><td>32815.312</td><td>33098.865</td><td>32515.195</td><td>27965.721</td><td>27559.521</td></tr><tr><td><b>512B</b></td><td>41296.271</td><td>39836.145</td><td>34193.811</td><td>34137.896</td><td>31802.303</td><td>26544.070</td><td>25715.543</td></tr>
#     </table>
# ---
# ---

# %% [markdown]
# ## Notes
#
# ### Definition of ***Steady State***
#
# ```
# A device is said to be in Steady State when, for the dependent variable (y)
# being tracked:
#     a) Range(y) is less than 10% of Ave(y): Max(y)-Min(y) within the
#        Measurement Window is no more than 10% of the Ave(y) within the
#        Measurement Window; and
#     b) Slope(y) is less than 10%: Max(y)-Min(y), where Max(y) and Min(y) are
#        the maximum and minimum values on the best linear curve fit of the
#        y-values within the Measurement Window, is within 10% of Ave(y) value
#        within the Measurement Window.
# ```

# %% [markdown]
# ## References
#
# - [Solid State Storage (SSS) Performance Test Specification (PTS) v2.0.1](https://www.snia.org/sites/default/files/technical_work/PTS/SSS_PTS_2.0.1.pdf)
