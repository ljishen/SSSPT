# %% [markdown]
# # Throughput Test Report

# %% [markdown]
# ## Experiment Environment

# %% [markdown]
# ### Part 2: SBC-based Experiment
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Platform</b></th>
#   </tr>
#   <tr>
#     <td><b>Ref Test Platform</b></td>
#     <td>ROCKPro64</td>
#   </tr>
#   <tr>
#     <td><b>CPU</b></td>
#     <td>Rockchip RK3399 (Dual Cortex-A72 @ 2.0GHz + Quad Cortex-A53 @ 1.5GHz)</td>
#   </tr>
#   <tr>
#     <td><b>Memory</b></td>
#     <td>4GB DDR4</td>
#   </tr>
#   <tr>
#     <td><b>Operating System</b></td>
#     <td>Ubuntu 18.04.1</td>
#   </tr>
#   <tr>
#     <td><b>Kernel Release</b></td>
#     <td>4.4.132-1075-rockchip-ayufan-ga83beded8524</td>
#   </tr>
#   <tr>
#     <td><b>Test SW</b></td>
#     <td>fio-3.8</td>
#   </tr>
#   <tr>
#     <td><b>HBA</b></td>
#     <td>Ugreen 20231 USB 3.0 to SATA 3.0 Converter Adapter</td>
#   </tr>
#   <tr>
#     <td><b>PCIe</b></td>
#     <td>Gen 2.1</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Device Under Test</b></th>
#   </tr>
#   <tr>
#     <td><b>Mfgr</b></td>
#     <td>Toshiba HG6</td>
#   </tr>
#   <tr>
#     <td><b>Model No.</b></td>
#     <td>THNSNJ256G8NU</td>
#   </tr>
#   <tr>
#     <td><b>S/N</b></td>
#     <td>15NS100WT9JW</td>
#   </tr>
#   <tr>
#     <td><b>Firmware Ver.</b></td>
#     <td>JUGB0101</td>
#   </tr>
#   <tr>
#     <td><b>Capacity</b></td>
#     <td>256 GB</td>
#   </tr>
#   <tr>
#     <td><b>Interface</b></td>
#     <td>SATA Rev 3.0<br></td>
#   </tr>
#   <tr>
#     <td><b>NAND Type</b></td>
#     <td>MLC</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <th colspan="2"><b>Set Up Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%<br></td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 1</b></td>
#     <td>SEQ 128KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32</td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 2</b></td>
#     <td>SEQ 1024KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32<br></td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%</td>
#   </tr>
#   <tr>
#     <td><b>Test Stimulus 1</b></td>
#     <td>SEQ</td>
#   </tr>
#   <tr>
#     <td>    Block Size (Outer Loop)</td>
#     <td>128KB, 1024KB</td>
#   </tr>
#   <tr>
#     <td>    R/W Mix (Inner Loop)</td>
#     <td>100:0, 0:100</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32</td>
#   </tr>
#   <tr>
#     <td>    Steady State</td>
#     <td>1 - 5</td>
#   </tr>
# </table>
#
# <p align="center">
#     <a href="https://docs.google.com/drawings/d/1GHbgPG3ra5o8HHPw8yKutmY5woE5rniVgiZERhlhWHQ/edit?usp=sharing"><img src="images/expr_setup_rockpro64.png" alt="Baseline Expr Setup (RockPro64)"></a>
# </p>

# %%
# %run 'common/plot_throughput.py'

profiles_dirname = 'rockpro64/throughput/1'

plot_ss_convergence(profiles_dirname)
plot_ss_measurement_window(profiles_dirname)
plot_tp_measurement(profiles_dirname)
# Out:
# ---
#             <table>
#               <caption><b>Block Size: 4KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>116.074 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>127.681 MB/s (Max) / 104.466 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>117.345 MB/s (Max) / 114.955 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.131% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.07627 x + 116.3</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 8KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>219.017 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>240.919 MB/s (Max) / 197.115 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>221.615 MB/s (Max) / 216.056 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.016% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.01768 x + 219.1</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 16KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>335.130 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>368.643 MB/s (Max) / 301.617 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>335.422 MB/s (Max) / 334.985 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.058% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.09756 x + 334.8</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 32KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>355.000 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>390.500 MB/s (Max) / 319.500 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>355.519 MB/s (Max) / 354.507 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.119% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.2109 x + 354.4</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 128KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>399.727 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>439.699 MB/s (Max) / 359.754 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>399.785 MB/s (Max) / 399.612 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.018% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.03584 x + 399.6</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 1024KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>416.518 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>458.170 MB/s (Max) / 374.866 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>416.538 MB/s (Max) / 416.505 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.002% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.004297 x + 416.5</td>
#               </tr>
#             </table><br/>
# ---
#             <table>
#               <caption><b>Block Size: 4KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>112.721 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>123.993 MB/s (Max) / 101.449 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>114.707 MB/s (Max) / 110.449 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.777% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.4382 x + 114</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 8KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>211.060 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>232.166 MB/s (Max) / 189.954 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>212.112 MB/s (Max) / 210.237 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.434% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.4578 x + 212.4</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 16KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>266.043 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>292.647 MB/s (Max) / 239.439 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>266.651 MB/s (Max) / 265.637 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.006% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.007715 x + 266.1</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 32KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>273.844 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>301.228 MB/s (Max) / 246.460 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>274.660 MB/s (Max) / 272.750 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.068% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.09297 x + 273.6</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 128KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>282.488 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>310.736 MB/s (Max) / 254.239 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>287.604 MB/s (Max) / 272.659 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>2.273% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -3.21 x + 292.1</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 1024KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>292.153 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>321.368 MB/s (Max) / 262.937 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>292.621 MB/s (Max) / 291.519 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.091% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.1331 x + 292.6</td>
#               </tr>
#             </table><br/>
# ---

# %% [markdown]
# ## Notes
#
# ### Definition of ***Steady State***
#
# ```
# A device is said to be in Steady State when, for the dependent variable (y)
# being tracked:
#     a) Range(y) is less than 10% of Ave(y): Max(y)-Min(y) within the
#        Measurement Window is no more than 10% of the Ave(y) within the
#        Measurement Window; and
#     b) Slope(y) is less than 10%: Max(y)-Min(y), where Max(y) and Min(y) are
#        the maximum and minimum values on the best linear curve fit of the
#        y-values within the Measurement Window, is within 10% of Ave(y) value
#        within the Measurement Window.
# ```

# %% [markdown]
# ## References
#
# - [Solid State Storage (SSS) Performance Test Specification (PTS) v2.0.1](https://www.snia.org/sites/default/files/technical_work/PTS/SSS_PTS_2.0.1.pdf)
