# %% [markdown]
# # Throughput Test Report

# %% [markdown]
# ## Experiment Environment

# %% [markdown]
# ### Part 2: SBC-based Experiment
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Platform</b></th>
#   </tr>
#   <tr>
#     <td><b>Ref Test Platform</b></td>
#     <td>ROCKPro64</td>
#   </tr>
#   <tr>
#     <td><b>CPU</b></td>
#     <td>Rockchip RK3399 (Dual Cortex-A72 @ 2.0GHz + Quad Cortex-A53 @ 1.5GHz)</td>
#   </tr>
#   <tr>
#     <td><b>Memory</b></td>
#     <td>4GB DDR4</td>
#   </tr>
#   <tr>
#     <td><b>Operating System</b></td>
#     <td>Ubuntu 18.04.1</td>
#   </tr>
#   <tr>
#     <td><b>Kernel Release</b></td>
#     <td>4.4.132-1075-rockchip-ayufan-ga83beded8524</td>
#   </tr>
#   <tr>
#     <td><b>Test SW</b></td>
#     <td>fio-3.8</td>
#   </tr>
#   <tr>
#     <td><b>HBA</b></td>
#     <td>Ugreen 20231 USB 3.0 to SATA 3.0 Converter Adapter</td>
#   </tr>
#   <tr>
#     <td><b>PCIe</b></td>
#     <td>Gen 2.1</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Device Under Test</b></th>
#   </tr>
#   <tr>
#     <td><b>Mfgr</b></td>
#     <td>Toshiba HG6</td>
#   </tr>
#   <tr>
#     <td><b>Model No.</b></td>
#     <td>THNSNJ256G8NU</td>
#   </tr>
#   <tr>
#     <td><b>S/N</b></td>
#     <td>15NS100WT9JW</td>
#   </tr>
#   <tr>
#     <td><b>Firmware Ver.</b></td>
#     <td>JUGB0101</td>
#   </tr>
#   <tr>
#     <td><b>Capacity</b></td>
#     <td>256 GB</td>
#   </tr>
#   <tr>
#     <td><b>Interface</b></td>
#     <td>SATA Rev 3.0<br></td>
#   </tr>
#   <tr>
#     <td><b>NAND Type</b></td>
#     <td>MLC</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#     <th colspan="2"><b>Set Up Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%<br></td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 1</b></td>
#     <td>SEQ 128KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32</td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 2</b></td>
#     <td>SEQ 1024KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32<br></td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%</td>
#   </tr>
#   <tr>
#     <td><b>Test Stimulus 1</b></td>
#     <td>SEQ</td>
#   </tr>
#   <tr>
#     <td>    Block Size (Outer Loop)</td>
#     <td>128KB, 1024KB</td>
#   </tr>
#   <tr>
#     <td>    R/W Mix (Inner Loop)</td>
#     <td>100:0, 0:100</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 32</td>
#   </tr>
#   <tr>
#     <td>    Steady State</td>
#     <td>1 - 5</td>
#   </tr>
# </table>
#
# <p align="center">
#     <a href="https://docs.google.com/drawings/d/1GHbgPG3ra5o8HHPw8yKutmY5woE5rniVgiZERhlhWHQ/edit?usp=sharing"><img src="images/expr_setup_rockpro64.png" alt="Baseline Expr Setup (RockPro64)"></a>
# </p>

# %%
# %run 'common/plot_throughput.py'

profiles_dirname = 'rockpro64/throughput/5'

plot_ss_convergence(profiles_dirname)
plot_ss_measurement_window(profiles_dirname)
plot_tp_measurement(profiles_dirname)
# Out:
# ---
#             <table>
#               <caption><b>Block Size: 4KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>116.408 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>128.049 MB/s (Max) / 104.767 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>117.915 MB/s (Max) / 114.835 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>1.380% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.8033 x + 118.8</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 8KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>220.751 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>242.826 MB/s (Max) / 198.676 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>221.839 MB/s (Max) / 219.825 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.267% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.2945 x + 221.6</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 16KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>334.835 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>368.318 MB/s (Max) / 301.351 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>335.174 MB/s (Max) / 334.649 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.002% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.003809 x + 334.8</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 32KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>368.326 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>405.158 MB/s (Max) / 331.493 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>368.585 MB/s (Max) / 368.109 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.044% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.08184 x + 368.6</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 128KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>394.384 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>433.823 MB/s (Max) / 354.946 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>394.509 MB/s (Max) / 393.946 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.025% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.0499 x + 394.5</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 1024KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>400.168 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>440.185 MB/s (Max) / 360.151 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>400.189 MB/s (Max) / 400.156 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.003% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.006348 x + 400.1</td>
#               </tr>
#             </table><br/>
# ---
#             <table>
#               <caption><b>Block Size: 4KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>113.242 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>124.566 MB/s (Max) / 101.918 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>113.928 MB/s (Max) / 112.025 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.054% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.03066 x + 113.3</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 8KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>211.247 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>232.372 MB/s (Max) / 190.122 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>212.184 MB/s (Max) / 210.400 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.321% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.3386 x + 212.3</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 16KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>266.989 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>293.688 MB/s (Max) / 240.291 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>267.854 MB/s (Max) / 266.345 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.141% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.1876 x + 267.6</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 32KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>273.581 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>300.939 MB/s (Max) / 246.223 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>274.137 MB/s (Max) / 272.543 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.160% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# 0.2188 x + 272.9</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 128KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>282.754 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>311.029 MB/s (Max) / 254.478 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>283.600 MB/s (Max) / 282.174 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.141% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.1998 x + 283.4</td>
#               </tr>
#             </table><br/>
#             <table>
#               <caption><b>Block Size: 1024KB</b></caption>
#               <tr>
#                 <td><b>Measurement Window</b></td>
#                 <td>1 - 5</td>
#               </tr>
#               <tr>
#                 <td><b>Ave. value in Measurement Window</b></td>
#                 <td>284.791 MB/s</td>
#               </tr>
#               <tr>
#                 <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#                 <td>313.270 MB/s (Max) / 256.312 MB/s (Min)</td>
#               </tr>
#               <tr>
#                 <td><b>Measured range in Measurement Window</b></td>
#                 <td>285.464 MB/s (Max) / 283.979 MB/s (Min)  (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#                 <td>0.007% (<b>pass</b>)</td>
#               </tr>
#               <tr>
#                 <td><b>Least Squares Linear Fit Formula</b></td>
#                 <td>
# -0.009668 x + 284.8</td>
#               </tr>
#             </table><br/>
# ---

# %% [markdown]
# ## Notes
#
# ### Definition of ***Steady State***
#
# ```
# A device is said to be in Steady State when, for the dependent variable (y)
# being tracked:
#     a) Range(y) is less than 10% of Ave(y): Max(y)-Min(y) within the
#        Measurement Window is no more than 10% of the Ave(y) within the
#        Measurement Window; and
#     b) Slope(y) is less than 10%: Max(y)-Min(y), where Max(y) and Min(y) are
#        the maximum and minimum values on the best linear curve fit of the
#        y-values within the Measurement Window, is within 10% of Ave(y) value
#        within the Measurement Window.
# ```

# %% [markdown]
# ## References
#
# - [Solid State Storage (SSS) Performance Test Specification (PTS) v2.0.1](https://www.snia.org/sites/default/files/technical_work/PTS/SSS_PTS_2.0.1.pdf)
