# %% [markdown]
# # Latency Test Report

# %% [markdown]
# ## Experiment Environment

# %% [markdown]
# <table>
#   <tr>
#     <th colspan="2"><b>Set Up Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%<br></td>
#   </tr>
#   <tr>
#     <td><b>Pre Condition 1</b></td>
#     <td>SEQ 128KB W</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 1</td>
#   </tr>
#   <tr>
#     <td>    Duration</td>
#     <td>2 x User Capacity</td>
#   </tr>
#   <tr>
#     <td><b>Purge Method</b></td>
#     <td>None</td>
#   </tr>
#   <tr>
#     <td><b>Write Cache</b></td>
#     <td>Enabled</td>
#   </tr>
# </table>
#
#
# <table>
#   <tr>
#     <th colspan="2"><b>Test Parameters</b></th>
#   </tr>
#   <tr>
#     <td><b>Active Range</b></td>
#     <td>75%</td>
#   </tr>
#   <tr>
#     <td><b>Test Stimulus 1</b></td>
#     <td>RND</td>
#   </tr>
#   <tr>
#     <td>    Block Size (Outer Loop)</td>
#     <td>8KB, 4KB, 512B</td>
#   </tr>
#   <tr>
#     <td>    R/W Mix (Inner Loop)</td>
#     <td>100/0, 65/35, 0/100</td>
#   </tr>
#   <tr>
#     <td>    TOIO - TC/QD</td>
#     <td>TC 1 / QD 1</td>
#   </tr>
# </table>

# %%
# %run 'common/plot_lat.py'

profiles_dirname = 'rockpro64/lat/1'

plot_ss_convergence(profiles_dirname)
plot_ss_measurement_window(profiles_dirname)
plot_measurement_window_tabular(profiles_dirname)
# Out:
# ---
# ---
# ---
# ---
#     <table>
#       <caption><b>Block Size = 4KB, R/W Mix % = 100:0</b></caption>
#       <tr>
#         <td><b>Measurement Window</b></td>
#         <td>1 - 5</td>
#       </tr>
#       <tr>
#         <td><b>Ave. value in Measurement Window</b></td>
#         <td>127743.362</td>
#       </tr>
#       <tr>
#         <td><b>Calculated allowed range in Measurement Window (+-10% of Ave.)</b></td>
#         <td>140517.698 (Max) / 114969.026 (Min)</td>
#       </tr>
#       <tr>
#         <td><b>Measured range in Measurement Window</b></td>
#         <td>131949.251 (Max) / 122062.826 (Min)  (<b>pass</b>)</td>
#       </tr>
#       <tr>
#         <td><b>Slope of best linear fit in Measurement Window (must be &lt;= 10%)</b></td>
#         <td>2.462% (<b>pass</b>)</td>
#       </tr>
#       <tr>
#         <td><b>Least Squares Linear Fit Formula</b></td>
#         <td>
# 1573 x + 1.23e+05</td>
#       </tr>
#     </table><br/>
# ---
#     <table>
#       <caption><b>Avg Latency (ns) - ALL RW Mix & BS - Tabular Data</b></caption>
#       <tr>
#         <td rowspan="2"><b>Block Size</b></td>
#         <td colspan="3"><b>Read / Write Mix %</b></td>
#       </tr>
#       <tr>
#         <td><b>100/0</b></td><td><b>65/35</b></td><td><b>0/100</b></td>
#       </tr>
#       <tr><td><b>8KB</b></td><td>146231.234</td><td>239165.768</td><td>188340.399</td></tr><tr><td><b>4KB</b></td><td>127743.362</td><td>173130.560</td><td>159184.134</td></tr><tr><td><b>512B</b></td><td>166827.690</td><td>167616.971</td><td>121473.606</td></tr>
#     </table>

# %% [markdown]
# ## Notes
#
# ### Definition of ***Steady State***
#
# ```
# A device is said to be in Steady State when, for the dependent variable (y)
# being tracked:
#     a) Range(y) is less than 10% of Ave(y): Max(y)-Min(y) within the
#        Measurement Window is no more than 10% of the Ave(y) within the
#        Measurement Window; and
#     b) Slope(y) is less than 10%: Max(y)-Min(y), where Max(y) and Min(y) are
#        the maximum and minimum values on the best linear curve fit of the
#        y-values within the Measurement Window, is within 10% of Ave(y) value
#        within the Measurement Window.
# ```
#
# ### Definition of ***Latency***
#
# ```
# The time between when the workload generator makes an IO request and when
# it receives notification of the request’s completion. In the context of using
# fio as the I/O generator, it denotes the time from when fio created the I/O
# unit to completion of the I/O operation.
# ```

# %% [markdown]
# ## References
#
# - [Solid State Storage (SSS) Performance Test Specification (PTS) v2.0.1](https://www.snia.org/sites/default/files/technical_work/PTS/SSS_PTS_2.0.1.pdf)
